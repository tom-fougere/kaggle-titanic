# %%
# Import
import pandas as pd
from sklearn.model_selection import train_test_split
from lib.Utils.dataframe_computation import *

# %%
# Read train data
data = pd.read_csv("data/train.csv")

# %%
# Head
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Summary
get_my_info(data)
# Out:
#                 Type  Count  Unique  Count_nan                         Top  \
# PassengerId    int64    891     891          0                         891
# Survived       int64    891       2          0                           0
# Pclass         int64    891       3          0                           3
# Name          object    891     891          0  Strom, Miss. Telma Matilda
# Sex           object    891       2          0                        male
# Age          float64    891      88        177                          24
# SibSp          int64    891       7          0                           0
# Parch          int64    891       7          0                           0
# Ticket        object    891     681          0                      347082
# Fare         float64    891     248          0                        8.05
# Cabin         object    891     147        687                 C23 C25 C27
# Embarked      object    891       3          2                           S
#
#              Freq      Mean   Median       Std   Min      Max
# PassengerId     1       446      446   257.354     1      891
# Survived      549  0.383838        0  0.486592     0        1
# Pclass        491   2.30864        3  0.836071     1        3
# Name            1      None     None      None  None     None
# Sex           577      None     None      None  None     None
# Age            30   29.6991       28   14.5265  0.42       80
# SibSp         608  0.523008        0   1.10274     0        8
# Parch         678  0.381594        0  0.806057     0        6
# Ticket          7      None     None      None  None     None
# Fare           43   32.2042  14.4542   49.6934     0  512.329
# Cabin           4      None     None      None  None     None
# Embarked      644      None     None      None  None     None

# %%
# Delete irrelevant columns
train = data.drop(['PassengerId', 'Survived', 'Name', 'Ticket', 'Cabin'], axis=1, inplace=False)

# %%
# Imputing Missing Values
train['Age'].fillna(train['Age'].mean(),inplace=True)
train['Embarked'].fillna(train['Embarked'].value_counts().index[0], inplace=True)
# Out:
#              Type  Count  Unique  Count_nan      Top  Freq      Mean   Median  \
# Pclass      int64    891       3          0        3   491   2.30864        3
# Sex        object    891       2          0     male   577      None     None
# Age       float64    891      89          0  29.6991   177   29.6991  29.6991
# SibSp       int64    891       7          0        0   608  0.523008        0
# Parch       int64    891       7          0        0   678  0.381594        0
# Fare      float64    891     248          0     8.05    43   32.2042  14.4542
# Embarked   object    891       3          0        S   646      None     None
#
#                Std   Min      Max
# Pclass    0.836071     1        3
# Sex           None  None     None
# Age         13.002  0.42       80
# SibSp      1.10274     0        8
# Parch     0.806057     0        6
# Fare       49.6934     0  512.329
# Embarked      None  None     None

# %%
# Getting Dummy Variables and Dropping the Original Categorical Variables
dummy_classes = ['Sex','Embarked']
categorical_variables = train[dummy_classes]
dummies = pd.get_dummies(categorical_variables, drop_first=True)
train = train.drop(dummy_classes, axis=1)
train = pd.concat([train, dummies], axis=1)

# %%
get_my_info(train)
# Out:
#                Type  Count  Unique  Count_nan        Top  Freq       Mean  \
# Pclass        int64    891       3          0   3.000000   491   2.308642
# Age         float64    891      89          0  29.699118   177  29.699118
# SibSp         int64    891       7          0   0.000000   608   0.523008
# Parch         int64    891       7          0   0.000000   678   0.381594
# Fare        float64    891     248          0   8.050000    43  32.204208
# Sex_male      uint8    891       2          0   1.000000   577   0.647587
# Embarked_Q    uint8    891       2          0   0.000000   814   0.086420
# Embarked_S    uint8    891       2          0   1.000000   646   0.725028
#
#                Median        Std   Min       Max
# Pclass       3.000000   0.836071  1.00    3.0000
# Age         29.699118  13.002015  0.42   80.0000
# SibSp        0.000000   1.102743  0.00    8.0000
# Parch        0.000000   0.806057  0.00    6.0000
# Fare        14.454200  49.693429  0.00  512.3292
# Sex_male     1.000000   0.477990  0.00    1.0000
# Embarked_Q   0.000000   0.281141  0.00    1.0000
# Embarked_S   1.000000   0.446751  0.00    1.0000

# %%
# Splitting data
y = data['Survived']
X = train
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
